# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Hyperspectral Image Datasets/Datasets/
# Out:
# /content/drive/MyDrive/Colab Notebooks/Hyperspectral Image Datasets/Data

# %% [markdown]
# # Import Libraries

# %%
# !pip install earthpy

# %%
# !pip install tensorflow_addons

# %%
# !pip install spectral
# Out:
# Collecting spectral
#   Downloading spectral-0.23.1-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from spectral) (1.25.2)
# Installing collected packages: spectral
# Successfully installed spectral-0.23.1

# %%
import sys
# Append the directory to your python path using sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/Project_Path')
# Import the module
import SWIN_Transformer_Model

# %%
import matplotlib.pyplot as plt

import numpy as np
import earthpy.plot as ep
import seaborn as sns
import earthpy.spatial as es

import plotly.graph_objects as go
import plotly.express as px

from scipy.io import loadmat

import pandas as pd

from sklearn.preprocessing import minmax_scale
from sklearn.model_selection import train_test_split
from sklearn.metrics import (accuracy_score,
                             confusion_matrix, classification_report)

import tensorflow as tf
from tensorflow import keras
from keras.layers import Input, Dense, MaxPooling2D, Dropout, Flatten, Conv2D, Conv3D, LeakyReLU, Reshape
from keras.models import Sequential
from keras.utils import to_categorical
from keras import layers
from keras.models import Model
from tensorflow.python.keras.utils import np_utils
import tensorflow_addons as tfa


from tqdm import tqdm
from numpy.random import seed
from time import time

from SWIN_Transformer_Model import PatchMerging, PatchExtract, PatchEmbedding, SwinTransformer
from operator import truediv
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, cohen_kappa_score
import spectral
from sklearn.decomposition import IncrementalPCA
from sklearn.decomposition import PCA

import os

seed(11)

# %% [markdown]
# # Load Data

# %%
################## X data (512, 217, 204)   Hyperspectral satellite   (512*217, 204)
data = loadmat('SA/Salinas_corrected.mat')['salinas_corrected']


###################### Y data (labels)
gt = loadmat('SA/Salinas_gt.mat')['salinas_gt']

print(f'Data Shape: {data.shape[:-1]}\nNumber of Bands: {data.shape[-1]}')
# Out:
# Data Shape: (512, 217)
# Number of Bands: 204

# %%
df = pd.DataFrame(data.reshape(data.shape[0]*data.shape[1], -1))

df.columns = [f'band{i}' for i in range(1, df.shape[-1]+1)]

df['class'] = gt.ravel()

# %%
df.head()
# Out:
#    band1  band2  band3  band4  band5  band6  band7  band8  band9  band10  ...  \
# 0    290    381    585   1041   1316   1397   1319   1462   1643    1683  ...
# 1    290    381    519   1041   1316   1352   1319   1462   1643    1683  ...
# 2    290    381    585   1041   1286   1352   1300   1412   1614    1644  ...
# 3    290    381    585    999   1316   1374   1280   1380   1584    1631  ...
# 4    219    381    585    999   1286   1352   1261   1396   1555    1618  ...
#
#    band196  band197  band198  band199  band200  band201  band202  band203  \
# 0       96      109       93       54       79       54       36       11
# 1       94      111       96       56       83       56       36       11
# 2       88      107       89       54       81       54       30       11
# 3       86      105       85       56       75       50       30       11
# 4       83      105       83       48       75       50       24        9
#
#    band204  class
# 0       17      0
# 1       15      0
# 2       11      0
# 3       19      0
# 4       17      0
#
# [5 rows x 205 columns]

# %%
df
# Out:
#         band1  band2  band3  band4  band5  band6  band7  band8  band9  band10  \
# 0         290    381    585   1041   1316   1397   1319   1462   1643    1683
# 1         290    381    519   1041   1316   1352   1319   1462   1643    1683
# 2         290    381    585   1041   1286   1352   1300   1412   1614    1644
# 3         290    381    585    999   1316   1374   1280   1380   1584    1631
# 4         219    381    585    999   1286   1352   1261   1396   1555    1618
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 111099    376    405    608   1043   1382   1446   1376   1526   1719    1760
# 111100    305    489    608   1086   1353   1446   1357   1510   1704    1760
# 111101    447    405    674   1128   1382   1446   1357   1493   1690    1760
# 111102    447    405    674   1086   1382   1424   1357   1493   1704    1734
# 111103    376    489    674   1128   1412   1446   1376   1493   1704    1760
#
#         ...  band196  band197  band198  band199  band200  band201  band202  \
# 0       ...       96      109       93       54       79       54       36
# 1       ...       94      111       96       56       83       56       36
# 2       ...       88      107       89       54       81       54       30
# 3       ...       86      105       85       56       75       50       30
# 4       ...       83      105       83       48       75       50       24
# ...     ...      ...      ...      ...      ...      ...      ...      ...
# 111099  ...      121      150      124       72      112       76       46
# 111100  ...      126      144      122       76      106       74       40
# 111101  ...      117      146      120       72      108       76       42
# 111102  ...      123      144      122       80      110       78       42
# 111103  ...      128      150      122       78      116       76       42
#
#         band203  band204  class
# 0            11       17      0
# 1            11       15      0
# 2            11       11      0
# 3            11       19      0
# 4             9       17      0
# ...         ...      ...    ...
# 111099       17       27      0
# 111100       13       21      0
# 111101       11       23      0
# 111102       17       27      0
# 111103       15       23      0
#
# [111104 rows x 205 columns]

# %%
df['class'].unique()
# Out:
# array([ 0,  6,  7,  4,  5, 15,  8,  3,  2,  1, 11, 12, 13, 14, 10,  9, 16],
#       dtype=uint8)

# %% [markdown]
# # Data Visualization

# %%
fig = plt.figure(figsize = (20, 12))

ax = fig.subplots(2, 5)

for i in range(2):
  for j in range(5):
    c = np.random.randint(103)
    ax[i][j].imshow(data[:, :, c], cmap='nipy_spectral')
    ax[i][j].axis('off')
    ax[i][j].title.set_text(f"Band - {c}")
    c+=1

plt.tight_layout()
plt.show()

# %% [markdown]
# # RGB Composite Image

# %%
mdata = np.moveaxis(data, -1, 0)

ep.plot_rgb(mdata, (29, 23, 0), figsize=(5, 5))

plt.show()

# %% [markdown]
# # GroundTruth Visualizaation

# %%
ep.plot_bands(gt, cmap='nipy_spectral', title='Ground Truth of IP', figsize=(7, 9))
plt.show()

# %% [markdown]
# # Data Preparation

# %%
## GLOBAL VARIABLES

# Proportion of the sample used for testing
test_ratio = 0.7
# Proportion of the sample used for Validation
val_ratio = 0.1
# Size of the extracted patch around each pixel
patch1_size = 25
# Number of principal components obtained by dimensionality reduction using PCA (original data: 30)
pca_components = 30
# classes
num_classes = 16
dataset='SA'

# %%
# Apply PCA transform to hyperspectral data X
def applyPCA(X, numComponents):
    newX = np.reshape(X, (-1, X.shape[2]))
    pca = PCA(n_components=numComponents, whiten=True)
    newX = pca.fit_transform(newX)
    newX = np.reshape(newX, (X.shape[0], X.shape[1], numComponents))
    return newX

# %%
# When extracting the patch around a single pixel, the edge pixels cannot be taken, so a padding operation is applied to this part of the pixel (margin original is 2)
def padWithZeros(X, margin=2):
    newX = np.zeros((X.shape[0] + 2 * margin, X.shape[1] + 2* margin, X.shape[2]))
    x_offset = margin
    y_offset = margin
    newX[x_offset:X.shape[0] + x_offset, y_offset:X.shape[1] + y_offset, :] = X
    return newX

# %%
# Extract the patch around each pixel and create it in a format that matches the keras processing (originally windowSize=5)
def createImageCubes(X, y, windowSize=8, removeZeroLabels = True):
    # for X to padding
    margin = int((windowSize ) / 2)  # hybirdcnn是（（windowsize-1）/2）
    zeroPaddedX = padWithZeros(X, margin=margin)
    # split patches
    patchesData = np.zeros((X.shape[0] * X.shape[1], windowSize, windowSize, X.shape[2]))
    patchesLabels = np.zeros((X.shape[0] * X.shape[1]))
    patchIndex = 0
    for r in range(margin, zeroPaddedX.shape[0] - margin):
        for c in range(margin, zeroPaddedX.shape[1] - margin):
            patch = zeroPaddedX[r - margin:r + margin + 1, c - margin:c + margin + 1]
            patchesData[patchIndex, :, :, :] = patch
            patchesLabels[patchIndex] = y[r-margin, c-margin]
            patchIndex = patchIndex + 1
    if removeZeroLabels:
        patchesData = patchesData[patchesLabels>0,:,:,:]
        patchesLabels = patchesLabels[patchesLabels>0]
        patchesLabels -= 1
    return patchesData, patchesLabels

# %%
def splitTrainTestSet(X, y, testRatio, randomState=345):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=testRatio, random_state=randomState, stratify=y)
    return X_train, X_test, y_train, y_test

# %%
print('Hyperspectral data shape: ', data.shape)
print('Label shape: ', gt.shape)
# Out:
# Hyperspectral data shape:  (512, 217, 204)
# Label shape:  (512, 217)

# %%
print('\n... ... PCA tranformation ... ...')
X = applyPCA(data, numComponents=pca_components)
print('Data shape after PCA: ', X.shape)
# Out:
# ... ... PCA tranformation ... ...
# Data shape after PCA:  (512, 217, 30)

# %%
#X, Y = createImageCubes(data, gt, windowSize=windowSize, removeZeroLabels = True)
#X.shape, Y.shape

print('\n... ... create data cubes ... ...')
X, Y = createImageCubes(X, gt, windowSize=patch1_size)
print('Data cube X shape: ', X.shape)
print('Data cube y shape: ', Y.shape)
# Out:
# ... ... create data cubes ... ...
# Data cube X shape:  (54129, 25, 25, 30)
# Data cube y shape:  (54129,)

# %%
# Reshape The X because we used 3D
#(n, W, H, B)
#(n, W, H, B, 1)
X = X.reshape((X.shape[0],patch1_size,patch1_size,30,1))
X.shape
# Out:
# (54129, 25, 25, 30, 1)

# %% [markdown]
# # Split Data

# %%
print('\n... ... create train & val & test data ... ...')
X_train, X_test, y_train, y_test = splitTrainTestSet(X, Y, test_ratio)
X_train, X_val, y_train, y_val = splitTrainTestSet(X_train, y_train, val_ratio)

print('X_train shape: ', X_train.shape)
print('X_val shape: ', X_val.shape)
print('X_test  shape: ', X_test.shape)
print('y_train shape: ',y_train.shape)
print('y_val shape: ',y_val.shape)
print('y_test shape:' , y_test.shape)
# Out:
# ... ... create train & val & test data ... ...
# X_train shape:  (14614, 25, 25, 30, 1)
# X_val shape:  (1624, 25, 25, 30, 1)
# X_test  shape:  (37891, 25, 25, 30, 1)
# y_train shape:  (14614,)
# y_val shape:  (1624,)
# y_test shape: (37891,)

# %%
# Change the shape of y_train, y_val and  to match keras
y_train=np_utils.to_categorical(y_train)
y_val=np_utils.to_categorical(y_val)
y_test=np_utils.to_categorical(y_test)

print('y_train shape: ',y_train.shape)
print('y_val shape: ',y_val.shape)
print('y_test shape:' , y_test.shape)
# Out:
# y_train shape:  (14614, 16)
# y_val shape:  (1624, 16)
# y_test shape: (37891, 16)

# %% [markdown]
# # Parameters and Functions

# %%
#input_shape = (25, 25, 30) #need to follow loading.shape and afterPCA ---> ip_shape
input_shape = (25, 25, 30, 1)

patch_size = (2, 2)  # 2-by-2 sized patches
dropout_rate = 0.03  # Dropout rate (origin0.03)
num_heads = 8  # Attention heads
embed_dim = 64  # Embedding dimension (origin64)
num_mlp = 256  # MLP layer size
qkv_bias = True  # Convert embedded patches to query, key, and values with a learnable additive value
window_size = 2  # Size of attention window
shift_size = 1  # Size of shifting window
image_dimension = 25  # Initial image size (origin32) （afterPCA25）（afterCNN module 17）

num_patch_x = input_shape[0] // patch_size[0]
num_patch_y = input_shape[1] // patch_size[1]

learning_rate = 1e-3
batch_size = 512
#num_epochs = 10
num_epochs = 1
validation_split = 0.1
weight_decay = 0.0001
label_smoothing = 0.1

# %% [markdown]
# # Build Model

# %%
imIn = Input(shape=input_shape)
imIn
# Out:
# <KerasTensor: shape=(None, 25, 25, 30, 1) dtype=float32 (created by layer 'input_1')>

# %%
# CNN Model
## 3D Convolutional Layers
conv_layer1 = Conv3D(filters=8, kernel_size=(3, 3, 7), activation='relu')(imIn)
conv_layer2 = Conv3D(filters=16, kernel_size=(3, 3, 5), activation='relu')(conv_layer1)
conv_layer3 = Conv3D(filters=32, kernel_size=(3, 3, 3), activation='relu')(conv_layer2)
print(conv_layer3.shape)
print("---------------------------")
conv3d_shape = conv_layer3.shape
conv_layer3 = Reshape((conv3d_shape[1], conv3d_shape[2], conv3d_shape[3]*conv3d_shape[4]))(conv_layer3)
print(conv_layer3.shape)
print("---------------------------")

#2DCNN
conv_layer4 =Conv2D(filters=64, kernel_size=(3,3), activation='relu')(conv_layer3)
print(conv_layer4.shape)
print("---------------------------")

# SWIN Transformer Layers
x = layers.RandomCrop(image_dimension, image_dimension)(conv_layer4)
print('random crop:',x.shape)
x = layers.RandomFlip("horizontal")(x)
print('random flip:',x.shape)
x = PatchExtract(patch_size)(x)
print('patch extract:',x.shape)
x = PatchEmbedding(num_patch_x * num_patch_y, embed_dim)(x)
print('patch embedding:',x.shape)
x = SwinTransformer(
    dim=embed_dim,
    num_patch=(num_patch_x, num_patch_y),
    num_heads=num_heads,
    window_size=window_size,
    shift_size=0,
    num_mlp=num_mlp,
    qkv_bias=qkv_bias,
    dropout_rate=dropout_rate,
)(x)
print('swin1:',x.shape)
x = SwinTransformer(
    dim=embed_dim,
    num_patch=(num_patch_x, num_patch_y),
    num_heads=num_heads,
    window_size=window_size,
    shift_size=shift_size,
    num_mlp=num_mlp,
    qkv_bias=qkv_bias,
    dropout_rate=dropout_rate,
)(x)
print('swin2:',x.shape)
x = PatchMerging((num_patch_x, num_patch_y), embed_dim=embed_dim)(x)
print('patchmerging:',x.shape)
x = layers.GlobalAveragePooling1D()(x)
print('global average pooling:',x.shape)
output = layers.Dense(num_classes, activation="softmax")(x)
print('out:',x.shape)
# Out:
# (None, 19, 19, 18, 32)
# ---------------------------
# (None, 19, 19, 576)
# ---------------------------
# (None, 17, 17, 64)
# ---------------------------
# random crop: (None, 25, 25, 64)
# random flip: (None, 25, 25, 64)
# patch extract: (None, 144, 256)
# patch embedding: (None, 144, 64)
# swin1: (None, 144, 64)
# swin2: (None, 144, 64)
# patchmerging: (None, 36, 128)
# global average pooling: (None, 128)
# out: (None, 128)

# %%
model = Model(inputs=[imIn], outputs=output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 25, 25, 30, 1)]   0
#
#  conv3d (Conv3D)             (None, 23, 23, 24, 8)     512
#
#  conv3d_1 (Conv3D)           (None, 21, 21, 20, 16)    5776
#
#  conv3d_2 (Conv3D)           (None, 19, 19, 18, 32)    13856
#
#  reshape (Reshape)           (None, 19, 19, 576)       0
#
#  conv2d (Conv2D)             (None, 17, 17, 64)        331840
#
#  random_crop (RandomCrop)    (None, 25, 25, 64)        0
#
#  random_flip (RandomFlip)    (None, 25, 25, 64)        0
#
#  patch_extract (PatchExtrac  (None, 144, 256)          0
#  t)
#
#  patch_embedding (PatchEmbe  (None, 144, 64)           25664
#  dding)
#
#  swin_transformer (SwinTran  (None, 144, 64)           50072
#  sformer)
#
#  swin_transformer_1 (SwinTr  (None, 144, 64)           50648
#  ansformer)
#
#  patch_merging (PatchMergin  (None, 36, 128)           32768
#  g)
#
#  global_average_pooling1d (  (None, 128)               0
#  GlobalAveragePooling1D)
#
#  dense_10 (Dense)            (None, 16)                2064
#
# =================================================================
# Total params: 513200 (1.96 MB)
# Trainable params: 512592 (1.96 MB)
# Non-trainable params: 608 (4.75 KB)
# _________________________________________________________________

# %% [markdown]
# ## Train Model

# %%
model.compile(
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=label_smoothing),
    optimizer=tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    ),
    metrics=[
        keras.metrics.CategoricalAccuracy(name="accuracy"),
    ],
)

# %%
start = time()

history = model.fit(
    X_train, #The display is modified: the original indicates x_train, y_train
    y_train, #
    batch_size=batch_size,
    epochs=100,
    validation_data = (X_val, y_val),
)

end = time()
print("\n Training Time:", (end-start))

# Save Training Hostry to CSV
history_data = pd.DataFrame(history.history)
history_data_csv_file = '/content/drive/MyDrive/Colab Notebooks/Save_Files/SA/SA_history.csv'
with open(history_data_csv_file, mode='w') as f:
    history_data.to_csv(f)
# Out:
# Epoch 1/100
# 29/29 [==============================] - 21s 276ms/step - loss: 2.3555 - accuracy: 0.4763 - val_loss: 0.9356 - val_accuracy: 0.9046
# Epoch 2/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.8003 - accuracy: 0.9622 - val_loss: 0.7122 - val_accuracy: 0.9877
# Epoch 3/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.6836 - accuracy: 0.9914 - val_loss: 0.6538 - val_accuracy: 0.9963
# Epoch 4/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.6442 - accuracy: 0.9961 - val_loss: 0.6335 - val_accuracy: 0.9951
# Epoch 5/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.6241 - accuracy: 0.9980 - val_loss: 0.6184 - val_accuracy: 0.9982
# Epoch 6/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.6118 - accuracy: 0.9984 - val_loss: 0.6083 - val_accuracy: 1.0000
# Epoch 7/100
# 29/29 [==============================] - 3s 108ms/step - loss: 0.6048 - accuracy: 0.9982 - val_loss: 0.6013 - val_accuracy: 0.9982
# Epoch 8/100
# 29/29 [==============================] - 3s 107ms/step - loss: 0.5973 - accuracy: 0.9990 - val_loss: 0.5956 - val_accuracy: 0.9994
# Epoch 9/100
# 29/29 [==============================] - 3s 107ms/step - loss: 0.5942 - accuracy: 0.9990 - val_loss: 0.5928 - val_accuracy: 0.9994
# Epoch 10/100
# 29/29 [==============================] - 3s 107ms/step - loss: 0.5905 - accuracy: 0.9997 - val_loss: 0.5901 - val_accuracy: 0.9994
# Epoch 11/100
# 29/29 [==============================] - 3s 107ms/step - loss: 0.5882 - accuracy: 0.9994 - val_loss: 0.5888 - val_accuracy: 1.0000
# Epoch 12/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5872 - accuracy: 0.9994 - val_loss: 0.5863 - val_accuracy: 1.0000
# Epoch 13/100
# 29/29 [==============================] - 3s 107ms/step - loss: 0.5858 - accuracy: 0.9996 - val_loss: 0.5852 - val_accuracy: 1.0000
# Epoch 14/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5842 - accuracy: 0.9997 - val_loss: 0.5847 - val_accuracy: 0.9994
# Epoch 15/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5845 - accuracy: 0.9997 - val_loss: 0.5855 - val_accuracy: 1.0000
# Epoch 16/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5828 - accuracy: 0.9996 - val_loss: 0.5810 - val_accuracy: 1.0000
# Epoch 17/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5814 - accuracy: 0.9998 - val_loss: 0.5812 - val_accuracy: 1.0000
# Epoch 18/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5806 - accuracy: 0.9998 - val_loss: 0.5813 - val_accuracy: 1.0000
# Epoch 19/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5805 - accuracy: 0.9999 - val_loss: 0.5803 - val_accuracy: 1.0000
# Epoch 20/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5805 - accuracy: 0.9997 - val_loss: 0.5795 - val_accuracy: 1.0000
# Epoch 21/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5792 - accuracy: 0.9999 - val_loss: 0.5797 - val_accuracy: 0.9994
# Epoch 22/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5790 - accuracy: 0.9999 - val_loss: 0.5792 - val_accuracy: 0.9994
# Epoch 23/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5783 - accuracy: 0.9999 - val_loss: 0.5783 - val_accuracy: 1.0000
# Epoch 24/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5776 - accuracy: 0.9999 - val_loss: 0.5774 - val_accuracy: 1.0000
# Epoch 25/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5773 - accuracy: 0.9999 - val_loss: 0.5774 - val_accuracy: 1.0000
# Epoch 26/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5775 - accuracy: 0.9999 - val_loss: 0.5783 - val_accuracy: 1.0000
# Epoch 27/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5775 - accuracy: 0.9999 - val_loss: 0.5774 - val_accuracy: 1.0000
# Epoch 28/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5770 - accuracy: 0.9999 - val_loss: 0.5775 - val_accuracy: 1.0000
# Epoch 29/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5761 - accuracy: 0.9999 - val_loss: 0.5770 - val_accuracy: 1.0000
# Epoch 30/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5759 - accuracy: 0.9998 - val_loss: 0.5763 - val_accuracy: 1.0000
# Epoch 31/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5757 - accuracy: 1.0000 - val_loss: 0.5756 - val_accuracy: 1.0000
# Epoch 32/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5754 - accuracy: 1.0000 - val_loss: 0.5755 - val_accuracy: 1.0000
# Epoch 33/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5751 - accuracy: 1.0000 - val_loss: 0.5753 - val_accuracy: 1.0000
# Epoch 34/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5749 - accuracy: 0.9999 - val_loss: 0.5763 - val_accuracy: 1.0000
# Epoch 35/100
# 29/29 [==============================] - 3s 107ms/step - loss: 0.5748 - accuracy: 0.9999 - val_loss: 0.5750 - val_accuracy: 1.0000
# Epoch 36/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5746 - accuracy: 0.9999 - val_loss: 0.5744 - val_accuracy: 1.0000
# Epoch 37/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5743 - accuracy: 1.0000 - val_loss: 0.5746 - val_accuracy: 1.0000
# Epoch 38/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5742 - accuracy: 1.0000 - val_loss: 0.5748 - val_accuracy: 1.0000
# Epoch 39/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5739 - accuracy: 1.0000 - val_loss: 0.5739 - val_accuracy: 1.0000
# Epoch 40/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5740 - accuracy: 1.0000 - val_loss: 0.5735 - val_accuracy: 1.0000
# Epoch 41/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5736 - accuracy: 1.0000 - val_loss: 0.5740 - val_accuracy: 1.0000
# Epoch 42/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5741 - accuracy: 1.0000 - val_loss: 0.5747 - val_accuracy: 1.0000
# Epoch 43/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5733 - accuracy: 1.0000 - val_loss: 0.5737 - val_accuracy: 1.0000
# Epoch 44/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5728 - accuracy: 1.0000 - val_loss: 0.5729 - val_accuracy: 1.0000
# Epoch 45/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5729 - accuracy: 1.0000 - val_loss: 0.5728 - val_accuracy: 1.0000
# Epoch 46/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5733 - accuracy: 1.0000 - val_loss: 0.5737 - val_accuracy: 1.0000
# Epoch 47/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5728 - accuracy: 1.0000 - val_loss: 0.5722 - val_accuracy: 1.0000
# Epoch 48/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5722 - accuracy: 1.0000 - val_loss: 0.5734 - val_accuracy: 1.0000
# Epoch 49/100
# 29/29 [==============================] - 3s 104ms/step - loss: 0.5728 - accuracy: 1.0000 - val_loss: 0.5728 - val_accuracy: 1.0000
# Epoch 50/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5723 - accuracy: 0.9999 - val_loss: 0.5731 - val_accuracy: 1.0000
# Epoch 51/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5720 - accuracy: 1.0000 - val_loss: 0.5729 - val_accuracy: 1.0000
# Epoch 52/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5718 - accuracy: 1.0000 - val_loss: 0.5723 - val_accuracy: 1.0000
# Epoch 53/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5718 - accuracy: 1.0000 - val_loss: 0.5728 - val_accuracy: 1.0000
# Epoch 54/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5716 - accuracy: 1.0000 - val_loss: 0.5718 - val_accuracy: 1.0000
# Epoch 55/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5714 - accuracy: 1.0000 - val_loss: 0.5718 - val_accuracy: 1.0000
# Epoch 56/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5713 - accuracy: 1.0000 - val_loss: 0.5712 - val_accuracy: 1.0000
# Epoch 57/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5709 - accuracy: 1.0000 - val_loss: 0.5711 - val_accuracy: 1.0000
# Epoch 58/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5707 - accuracy: 1.0000 - val_loss: 0.5712 - val_accuracy: 1.0000
# Epoch 59/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5707 - accuracy: 1.0000 - val_loss: 0.5716 - val_accuracy: 1.0000
# Epoch 60/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5708 - accuracy: 1.0000 - val_loss: 0.5723 - val_accuracy: 0.9994
# Epoch 61/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5704 - accuracy: 1.0000 - val_loss: 0.5707 - val_accuracy: 1.0000
# Epoch 62/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5704 - accuracy: 1.0000 - val_loss: 0.5718 - val_accuracy: 1.0000
# Epoch 63/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5704 - accuracy: 1.0000 - val_loss: 0.5715 - val_accuracy: 1.0000
# Epoch 64/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5704 - accuracy: 1.0000 - val_loss: 0.5709 - val_accuracy: 1.0000
# Epoch 65/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5703 - accuracy: 1.0000 - val_loss: 0.5708 - val_accuracy: 1.0000
# Epoch 66/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5703 - accuracy: 0.9999 - val_loss: 0.5706 - val_accuracy: 1.0000
# Epoch 67/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5700 - accuracy: 1.0000 - val_loss: 0.5711 - val_accuracy: 1.0000
# Epoch 68/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5699 - accuracy: 1.0000 - val_loss: 0.5707 - val_accuracy: 1.0000
# Epoch 69/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5699 - accuracy: 1.0000 - val_loss: 0.5705 - val_accuracy: 1.0000
# Epoch 70/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5699 - accuracy: 1.0000 - val_loss: 0.5703 - val_accuracy: 1.0000
# Epoch 71/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5696 - accuracy: 1.0000 - val_loss: 0.5704 - val_accuracy: 1.0000
# Epoch 72/100
# 29/29 [==============================] - 3s 107ms/step - loss: 0.5698 - accuracy: 1.0000 - val_loss: 0.5703 - val_accuracy: 1.0000
# Epoch 73/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5698 - accuracy: 1.0000 - val_loss: 0.5704 - val_accuracy: 1.0000
# Epoch 74/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5694 - accuracy: 1.0000 - val_loss: 0.5700 - val_accuracy: 1.0000
# Epoch 75/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5693 - accuracy: 1.0000 - val_loss: 0.5701 - val_accuracy: 1.0000
# Epoch 76/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5691 - accuracy: 1.0000 - val_loss: 0.5697 - val_accuracy: 1.0000
# Epoch 77/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5691 - accuracy: 1.0000 - val_loss: 0.5698 - val_accuracy: 1.0000
# Epoch 78/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5694 - accuracy: 1.0000 - val_loss: 0.5703 - val_accuracy: 1.0000
# Epoch 79/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5692 - accuracy: 1.0000 - val_loss: 0.5703 - val_accuracy: 1.0000
# Epoch 80/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5691 - accuracy: 1.0000 - val_loss: 0.5697 - val_accuracy: 1.0000
# Epoch 81/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5688 - accuracy: 1.0000 - val_loss: 0.5694 - val_accuracy: 1.0000
# Epoch 82/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5690 - accuracy: 1.0000 - val_loss: 0.5693 - val_accuracy: 1.0000
# Epoch 83/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5692 - accuracy: 1.0000 - val_loss: 0.5696 - val_accuracy: 1.0000
# Epoch 84/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5690 - accuracy: 1.0000 - val_loss: 0.5689 - val_accuracy: 1.0000
# Epoch 85/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5689 - accuracy: 1.0000 - val_loss: 0.5689 - val_accuracy: 1.0000
# Epoch 86/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5687 - accuracy: 1.0000 - val_loss: 0.5694 - val_accuracy: 1.0000
# Epoch 87/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5688 - accuracy: 1.0000 - val_loss: 0.5690 - val_accuracy: 1.0000
# Epoch 88/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5687 - accuracy: 1.0000 - val_loss: 0.5692 - val_accuracy: 1.0000
# Epoch 89/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5685 - accuracy: 1.0000 - val_loss: 0.5687 - val_accuracy: 1.0000
# Epoch 90/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5686 - accuracy: 1.0000 - val_loss: 0.5688 - val_accuracy: 1.0000
# Epoch 91/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5684 - accuracy: 1.0000 - val_loss: 0.5688 - val_accuracy: 1.0000
# Epoch 92/100
# 29/29 [==============================] - 3s 106ms/step - loss: 0.5682 - accuracy: 1.0000 - val_loss: 0.5687 - val_accuracy: 1.0000
# Epoch 93/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5682 - accuracy: 1.0000 - val_loss: 0.5683 - val_accuracy: 1.0000
# Epoch 94/100
# 29/29 [==============================] - 3s 107ms/step - loss: 0.5680 - accuracy: 1.0000 - val_loss: 0.5682 - val_accuracy: 1.0000
# Epoch 95/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5681 - accuracy: 1.0000 - val_loss: 0.5689 - val_accuracy: 1.0000
# Epoch 96/100
# 29/29 [==============================] - 3s 104ms/step - loss: 0.5679 - accuracy: 1.0000 - val_loss: 0.5681 - val_accuracy: 1.0000
# Epoch 97/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5679 - accuracy: 1.0000 - val_loss: 0.5682 - val_accuracy: 1.0000
# Epoch 98/100
# 29/29 [==============================] - 3s 104ms/step - loss: 0.5680 - accuracy: 1.0000 - val_loss: 0.5680 - val_accuracy: 1.0000
# Epoch 99/100
# 29/29 [==============================] - 3s 105ms/step - loss: 0.5678 - accuracy: 1.0000 - val_loss: 0.5680 - val_accuracy: 1.0000
# Epoch 100/100
# 29/29 [==============================] - 3s 104ms/step - loss: 0.5677 - accuracy: 1.0000 - val_loss: 0.5675 - val_accuracy: 1.0000
#
#  Training Time: 326.2931866645813

# %% [markdown]
# ## Result

# %%
plt.plot(history.history["accuracy"], label="Train_accuracy")
plt.plot(history.history["val_accuracy"], label="Val_accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Train and Validation Accuracies Over Epochs", fontsize=14)
plt.legend()
#plt.grid()
plt.show()

# %%
plt.plot(history.history["loss"], label="Train_loss")
plt.plot(history.history["val_loss"], label="Val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
#plt.grid()
plt.show()

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test loss: {round(loss, 2)}")
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
# Out:
# 1185/1185 [==============================] - 10s 8ms/step - loss: 0.5677 - accuracy: 1.0000
# Test loss: 0.57
# Test accuracy: 100.0%

# %%
Y_pred_test = model.predict(X_test)
y_pred_test = np.argmax(Y_pred_test, axis=1)

classification = classification_report(np.argmax(y_test, axis=1), y_pred_test)
print(classification)
# Out:
# 1185/1185 [==============================] - 10s 8ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1406
#            1       1.00      1.00      1.00      2608
#            2       1.00      1.00      1.00      1383
#            3       1.00      1.00      1.00       976
#            4       1.00      1.00      1.00      1875
#            5       1.00      1.00      1.00      2771
#            6       1.00      1.00      1.00      2505
#            7       1.00      1.00      1.00      7890
#            8       1.00      1.00      1.00      4342
#            9       1.00      1.00      1.00      2295
#           10       1.00      1.00      1.00       748
#           11       1.00      1.00      1.00      1349
#           12       1.00      1.00      1.00       641
#           13       1.00      1.00      1.00       749
#           14       1.00      1.00      1.00      5088
#           15       1.00      1.00      1.00      1265
#
#     accuracy                           1.00     37891
#    macro avg       1.00      1.00      1.00     37891
# weighted avg       1.00      1.00      1.00     37891

# %% [markdown]
# ## Classification Map

# %%
def AA_andEachClassAccuracy(confusion_matrix):
    counter = confusion_matrix.shape[0]
    list_diag = np.diag(confusion_matrix)
    list_raw_sum = np.sum(confusion_matrix, axis=1)
    each_acc = np.nan_to_num(truediv(list_diag, list_raw_sum))
    average_acc = np.mean(each_acc)
    return each_acc, average_acc

# %%
def reports (X_test,y_test,name):
    #start = time.time()
    Y_pred = model.predict(X_test)
    y_pred = np.argmax(Y_pred, axis=1)
    #end = time.time()
    #print(end - start)
    if name == 'IP':
        target_names = ['Alfalfa', 'Corn-notill', 'Corn-mintill', 'Corn'
                        ,'Grass-pasture', 'Grass-trees', 'Grass-pasture-mowed',
                        'Hay-windrowed', 'Oats', 'Soybean-notill', 'Soybean-mintill',
                        'Soybean-clean', 'Wheat', 'Woods', 'Buildings-Grass-Trees-Drives',
                        'Stone-Steel-Towers']
    elif name == 'SA':
        target_names = ['Brocoli_green_weeds_1','Brocoli_green_weeds_2','Fallow','Fallow_rough_plow','Fallow_smooth',
                        'Stubble','Celery','Grapes_untrained','Soil_vinyard_develop','Corn_senesced_green_weeds',
                        'Lettuce_romaine_4wk','Lettuce_romaine_5wk','Lettuce_romaine_6wk','Lettuce_romaine_7wk',
                        'Vinyard_untrained','Vinyard_vertical_trellis']
    elif name == 'PU':
        target_names = ['Asphalt','Meadows','Gravel','Trees', 'Painted metal sheets','Bare Soil','Bitumen',
                        'Self-Blocking Bricks','Shadows']

    classification = classification_report(np.argmax(y_test, axis=1), y_pred, target_names=target_names)
    oa = accuracy_score(np.argmax(y_test, axis=1), y_pred)
    confusion = confusion_matrix(np.argmax(y_test, axis=1), y_pred)
    each_acc, aa = AA_andEachClassAccuracy(confusion)
    kappa = cohen_kappa_score(np.argmax(y_test, axis=1), y_pred)
    score = model.evaluate(X_test, y_test, batch_size=32)
    Test_Loss =  score[0]*100
    Test_accuracy = score[1]*100

    return classification, confusion, Test_Loss, Test_accuracy, oa*100, each_acc*100, aa*100, kappa*100

# %%
classification, confusion, Test_loss, Test_accuracy, oa, each_acc, aa, kappa = reports(X_test,y_test,dataset)
classification = str(classification)
confusion = str(confusion)
print(classification)
file_name = "/content/drive/MyDrive/Colab Notebooks/Save_Files/SA/SA_classification_report.txt"

with open(file_name, 'w') as x_file:
    x_file.write('{} Test loss (%)'.format(Test_loss))
    x_file.write('\n')
    x_file.write('{} Test accuracy (%)'.format(Test_accuracy))
    x_file.write('\n')
    x_file.write('\n')
    x_file.write('{} Kappa accuracy (%)'.format(kappa))
    x_file.write('\n')
    x_file.write('{} Overall accuracy (%)'.format(oa))
    x_file.write('\n')
    x_file.write('{} Average accuracy (%)'.format(aa))
    x_file.write('\n')
    x_file.write('\n')
    x_file.write('{}'.format(classification))
    x_file.write('\n')
    x_file.write('{}'.format(confusion))
# Out:
# 1185/1185 [==============================] - 9s 8ms/step
# 1185/1185 [==============================] - 10s 8ms/step - loss: 0.5677 - accuracy: 1.0000
#                            precision    recall  f1-score   support
#
#     Brocoli_green_weeds_1       1.00      1.00      1.00      1406
#     Brocoli_green_weeds_2       1.00      1.00      1.00      2608
#                    Fallow       1.00      1.00      1.00      1383
#         Fallow_rough_plow       1.00      1.00      1.00       976
#             Fallow_smooth       1.00      1.00      1.00      1875
#                   Stubble       1.00      1.00      1.00      2771
#                    Celery       1.00      1.00      1.00      2505
#          Grapes_untrained       1.00      1.00      1.00      7890
#      Soil_vinyard_develop       1.00      1.00      1.00      4342
# Corn_senesced_green_weeds       1.00      1.00      1.00      2295
#       Lettuce_romaine_4wk       1.00      1.00      1.00       748
#       Lettuce_romaine_5wk       1.00      1.00      1.00      1349
#       Lettuce_romaine_6wk       1.00      1.00      1.00       641
#       Lettuce_romaine_7wk       1.00      1.00      1.00       749
#         Vinyard_untrained       1.00      1.00      1.00      5088
#  Vinyard_vertical_trellis       1.00      1.00      1.00      1265
#
#                  accuracy                           1.00     37891
#                 macro avg       1.00      1.00      1.00     37891
#              weighted avg       1.00      1.00      1.00     37891

# %% [markdown]
# # Show predicted image

# %%
def Patch(data,height_index,width_index):
    height_slice = slice(height_index, height_index+PATCH_SIZE)
    width_slice = slice(width_index, width_index+PATCH_SIZE)
    patch = data[height_slice, width_slice, :]
    return patch

# K after PCA
K = 30
windowSize1 = 25

# %%
X = loadmat('SA/Salinas_corrected.mat')['salinas_corrected']
y = loadmat('SA/Salinas_gt.mat')['salinas_gt']

height = y.shape[0]
width = y.shape[1]
PATCH_SIZE = windowSize1
numComponents = K

X = applyPCA(X, numComponents= pca_components)
X = padWithZeros(X, PATCH_SIZE//2)

# calculate the predicted image
outputs = np.zeros((height,width))
for i in tqdm(range(height)):
    for j in range(width):
        target = int(y[i,j])
        if target == 0 :
            continue
        else :
            image_patch=Patch(X,i,j)
            X_test_image = image_patch.reshape(1,image_patch.shape[0],image_patch.shape[1], image_patch.shape[2],1).astype('float32')
            prediction = (model.predict(X_test_image))
            prediction = np.argmax(prediction, axis=1)
            outputs[i][j] = prediction+1
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
ground_truth = spectral.imshow(classes = y,figsize =(7,7))
predict_image = spectral.imshow(classes = outputs.astype(int),figsize =(7,7))
spectral.save_rgb("/content/drive/MyDrive/Colab Notebooks/Save_Files/SA/SA_predictions.jpg", outputs.astype(int), colors=spectral.spy_colors)
spectral.save_rgb("/content/drive/MyDrive/Colab Notebooks/Save_Files/SA/SA_ground_truth.png", y, colors=spectral.spy_colors)
# Out:
# /usr/local/lib/python3.10/dist-packages/spectral/graphics/spypylab.py:796: UserWarning: Failed to create RectangleSelector object. Interactive pixel class labeling will be unavailable.
#   warnings.warn(msg)
